# %%
from src.google_flight_analysis.scrape import Scrape

# %%
x = Scrape("BIL", "SYD", "2023-07-09")
x.run_scrape()
print(x.url)
x.data
# Out:
# https://www.google.com/travel/flights?q=Flights%20to%20SYD%20from%20BIL%20on%202023-07-09%20oneway&curr=EUR&gl=IT
#    departure_datetime    arrival_datetime            airlines  travel_time
# 0 2023-07-09 14:33:00 2023-07-11 06:55:00            [United]         1462  \
# 1 2023-07-09 13:19:00 2023-07-11 06:35:00             [Delta]         1516
# 2 2023-07-09 14:02:00 2023-07-11 07:05:00          [American]         1503
# 3 2023-07-09 12:26:00 2023-07-11 07:45:00  [American, Qantas]         1639
# 4 2023-07-09 06:50:00 2023-07-11 07:45:00    [Alaska, Qantas]         1975
#
#   origin destination  layover_n  layover_time layover_location  price_eur
# 0    BIL         SYD          2          1440              min       1543  \
# 1    BIL         SYD          2          1500              min       1588
# 2    BIL         SYD          2          1920              min       1661
# 3    BIL         SYD          2          1920              min       2372
# ...

# %%
# Out:
#    departure_datetime    arrival_datetime           airlines  travel_time
# 0 2023-07-07 11:35:00 2023-07-07 13:15:00        [Eurowings]          100  \
# 1 2023-07-07 08:30:00 2023-07-07 12:40:00              [ITA]          250
# 2 2023-07-07 17:25:00 2023-07-07 21:00:00        [Lufthansa]          215
# 3 2023-07-07 08:30:00 2023-07-07 12:10:00              [ITA]          220
# 4 2023-07-07 06:00:00 2023-07-07 10:00:00        [Lufthansa]          240
# 5 2023-07-07 15:15:00 2023-07-07 20:40:00         [Austrian]          325
# 6 2023-07-07 12:20:00 2023-07-07 17:15:00  [Vueling, Iberia]          295
# 7 2023-07-07 14:15:00 2023-07-07 18:45:00              [KLM]          270
#
#   origin destination  layover_n  layover_time layover_location  price_eur
# 0    STR         FCO          0           NaN             None         55  \
# 1    STR         FCO          1         110.0              LIN         99
# 2    STR         FCO          1          85.0              MUC        176
# ...

# %%
x.url
# Out:
# 'https://www.google.com/travel/flights?q=Flights%20to%20FCO%20from%20FMM%20on%202023-07-07%20oneway&curr=EUR&gl=IT'
