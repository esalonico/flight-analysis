# %%
from src.google_flight_analysis.scrape import Scrape

# %%
x = Scrape("FCO", "MUC", "2023-07-05")

# %%
x.run_scrape()

# %%
x.data
# Out:
#    departure_datetime    arrival_datetime              airlines travel_time
# 0 2023-07-05 15:30:00 2023-07-05 20:15:00  Eurowings, Lufthansa       04:45  \
# 1 2023-07-05 16:15:00 2023-07-05 17:50:00                   ITA       01:35
# 2 2023-07-05 18:55:00 2023-07-05 20:30:00             Lufthansa       01:35
# 3 2023-07-05 15:55:00 2023-07-05 19:55:00  Eurowings, Lufthansa       04:00
# 4 2023-07-05 18:25:00 2023-07-06 09:30:00            Air France       15:05
# 5 2023-07-05 10:50:00 2023-07-05 12:25:00             Lufthansa       01:35
# 6 2023-07-05 12:55:00 2023-07-05 14:30:00             Lufthansa       01:35
# 7 2023-07-05 08:00:00 2023-07-05 09:35:00             Lufthansa       01:35
# 8 2023-07-05 20:15:00 2023-07-06 11:04:00      SWISS, Lufthansa       14:49
#
#            origin     destination  layover_n layover_time layover_location
# 0             FCO             MUC          1        01:10              HAM  \
# ...

# %%
x.url
# Out:
# 'https://www.google.com/travel/flights?q=Flights%20to%20MUC%20from%20FCO%20on%202023-07-05%20oneway'
