# %%
import pandas as pd
import matplotlib.pyplot as plt
from pymongo import MongoClient

from src.google_flight_analysis.scrape import Scrape

# %%
x = Scrape("FCO", "LAX", "2023-07-05")

# %%
x.run_scrape()

# %%
x.data
# Out:
#    departure_datetime    arrival_datetime                          airlines
# 0 2023-07-05 21:35:00 2023-07-06 14:10:00  Separate tickets booked together  \
# 1 2023-07-05 18:10:00 2023-07-05 09:15:00  Separate tickets booked together
# 2 2023-07-05 13:05:00 2023-07-05 21:25:00                               ITA
# 3 2023-07-05 07:00:00 2023-07-05 22:49:00      Lufthansa, Condor, Jet, Blue
# 4 2023-07-05 06:00:00 2023-07-05 21:23:00       Tap Air Portugal, Jet, Blue
# 5 2023-07-05 07:00:00 2023-07-05 18:10:00  Separate tickets booked together
# 6 2023-07-05 20:25:00 2023-07-06 18:30:00                        Aer Lingus
# 7 2023-07-05 22:35:00 2023-07-05 11:10:00                       Air Transat
# 8 2023-07-05 18:30:00 2023-07-05 06:30:00                        Aer Lingus
#
#   travel_time origin destination  layover_n layover_time layover_location
# 0       25:35    FCO         LAX          1        11:20              LGW  \
# ...

# %%
x.url
# Out:
# 'https://www.google.com/travel/flights?q=Flights%20to%20LAX%20from%20FCO%20on%202023-07-05%20oneway'
